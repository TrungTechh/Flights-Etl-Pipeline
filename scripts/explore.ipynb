# %%
import pandas as pd
import time

# %%
start = time.time()

print("FILE LOADED! This took", time.time() - start, " seconds")
df = pd.read_csv(
    "../data/itineraries.csv",
    chunksize=100000
)
# Out:
# FILE LOADED! This took 0.0  seconds

# %%
temp_df = None
for chunk in df:
    temp_df = chunk
    break

# %%
with pd.option_context('display.max_columns', None):
    display(temp_df)
# Out:
#                                   legId  searchDate  flightDate  \
# 0      9ca0e81111c683bec1012473feefd28f  2022-04-16  2022-04-17
# 1      98685953630e772a098941b71906592b  2022-04-16  2022-04-17
# 2      98d90cbc32bfbb05c2fc32897c7c1087  2022-04-16  2022-04-17
# 3      969a269d38eae583f455486fa90877b4  2022-04-16  2022-04-17
# 4      980370cf27c89b40d2833a1d5afc9751  2022-04-16  2022-04-17
# ...                                 ...         ...         ...
# 99995  02a4d527796ca5bd8be5b0e8e3d85acd  2022-04-17  2022-04-19
# 99996  416ff0256a24791b8924f91c354901ac  2022-04-17  2022-04-19
# 99997  e7806daf62b3d0eb0f801337bacdc496  2022-04-17  2022-04-19
# 99998  baac14d391f0026f78698e0915f92818  2022-04-17  2022-04-19
# 99999  61464bc6b979fa0cfba42d370a1da2a5  2022-04-17  2022-04-19
#
#       startingAirport destinationAirport fareBasisCode travelDuration  \
# 0                 ATL                BOS      LA0NX0MC        PT2H29M
# ...

# %%
count = 0
temp_df = None
for chunk in df:
    print(chunk.shape)
    count += 1
    print(count)
# Out:
# (1000000, 27)
# 1
# (1000000, 27)
# 2
# (1000000, 27)
# 3
# (1000000, 27)
# 4
# (1000000, 27)
# 5
# (1000000, 27)
# 6
# (1000000, 27)
# 7
# (1000000, 27)
# 8
# (1000000, 27)
# 9
# (1000000, 27)
# 10
# (1000000, 27)
# 11
# (1000000, 27)
# 12
# (1000000, 27)
# 13
# (1000000, 27)
# 14
# (1000000, 27)
# 15
# (1000000, 27)
# 16
# (1000000, 27)
# 17
# (1000000, 27)
# 18
# (1000000, 27)
# 19
# (1000000, 27)
# 20
# (1000000, 27)
# 21
# (1000000, 27)
# 22
# (1000000, 27)
# 23
# (1000000, 27)
# 24
# (1000000, 27)
# 25
# (1000000, 27)
# 26
# (1000000, 27)
# 27
# (1000000, 27)
# 28
# (1000000, 27)
# 29
# (1000000, 27)
# 30
# (1000000, 27)
# 31
# (1000000, 27)
# 32
# (1000000, 27)
# 33
# (1000000, 27)
# 34
# (1000000, 27)
# 35
# (1000000, 27)
# 36
# (1000000, 27)
# 37
# (1000000, 27)
# 38
# (1000000, 27)
# 39
# (1000000, 27)
# 40
# (1000000, 27)
# 41
# (1000000, 27)
# 42
# (1000000, 27)
# 43
# (1000000, 27)
# 44
# (1000000, 27)
# 45
# (1000000, 27)
# 46
# (1000000, 27)
# 47
# (1000000, 27)
# 48
# ...
